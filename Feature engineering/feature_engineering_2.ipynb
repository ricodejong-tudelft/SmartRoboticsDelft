# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from itertools import zip_longest
import os
import random

# %%
filename_in = "C:\\Users\\ricod\\Documents\\ads_measurements\\dataset_out.csv"

dataset = pd.read_csv(filename_in, index_col=0)
dataset.head(10)
# Out:
#     expected_weight  run_index  force_sensor_value  force_vector_1  \
# 1             0.335        1.0            0.347914       -0.286043
# 2             0.092        2.0            0.089347        0.075095
# 3             0.323        3.0            0.286799       -0.368245
# 4             0.116        4.0            0.082121       -0.131154
# 5             0.253        5.0            0.256462       -0.042422
# 6             0.284        6.0            0.293209        0.000913
# 7             0.193        7.0            0.191296       -0.556050
# 8             0.076        8.0            0.077536        0.063514
# 9             0.162        9.0            0.168201       -0.095890
# 10            0.120       10.0            0.151583       -0.253365
#
#     force_vector_2  force_vector_3  robot_tcp.velocity_linear_1  \
# 1        -0.248598       17.870183                     0.366421
# 2        -0.013662       16.856833                    -0.000090
# ...
